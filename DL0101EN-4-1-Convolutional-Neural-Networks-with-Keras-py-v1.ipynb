# %% [markdown]
# <a href="https://cognitiveclass.ai"><img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DL0101EN-SkillsNetwork/images/IDSN-logo.png" width="400"> </a>
#
# # Convolutional Neural Networks with Keras
#
# Estimated time needed **30** mins

# %% [markdown]
# In this lab, we will learn how to use the Keras library to build convolutional neural networks. We will also use the popular MNIST dataset and we will compare our results to using a conventional neural network.

# %% [markdown]
# ## Objectives for this Notebook
# * How to use the Keras library to build convolutional neural networks
# * Convolutional neural network with one set of convolutional and pooling layers
# * Convolutional neural network with two sets of convolutional and pooling layers

# %% [markdown]
# ## Table of Contents
#
# <div class="alert alert-block alert-info" style="margin-top: 20px">
#
# <font size = 3>
#
# 1. <a href="#Import-Keras-and-Packages">Import Keras and Packages</a>
# 2. <a href="#Convolutional-Neural-Network-with-One-Set-of-Convolutional-and-Pooling-Layers">Convolutional Neural Network with One Set of Convolutional and Pooling Layers</a>
# 3. <a href="#Convolutional-Neural-Network-with-Two-Sets-of-Convolutional-and-Pooling-Layers">Convolutional Neural Network with Two Sets of Convolutional and Pooling Layers</a>
#
# </font>
# </div>

# %% [markdown]
# ### Install the necessary libraries

# %% [markdown]
# Let's start by installing the keras libraries and the packages that we would need to build a neural network.

# %%
# All Libraries required for this lab are listed below. The libraries need to be installed on Skills Network Labs. 
# If you run this notebook on a different environment, e.g. your desktop, you may want to install these.
# !pip install numpy==2.0.2
# !pip install pandas==2.2.2
# !pip install tensorflow_cpu==2.18.0
# !pip install matplotlib==3.9.2

# %% [markdown]
# #### Suppress the tensorflow warning messages
# We use the following code to  suppress the warning messages due to use of CPU architechture for tensoflow.
# You may want to **comment out** these lines if you are using the GPU architechture

# %%
import os
os.environ['TF_ENABLE_ONEDNN_OPTS'] = '0'
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'

# %% [markdown]
# ## Import Keras and Packages

# %%
import keras
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Input
from keras.utils import to_categorical

# %% [markdown]
# When working with convolutional neural networks in particular, we will need additional packages.

# %%
from keras.layers import Conv2D # to add convolutional layers
from keras.layers import MaxPooling2D # to add pooling layers
from keras.layers import Flatten # to flatten data for fully connected layers

# %% [markdown]
# ## Convolutional Neural Network with One Set of Convolutional and Pooling Layers

# %%
# import data
from keras.datasets import mnist

# load data
(X_train, y_train), (X_test, y_test) = mnist.load_data()

# reshape to be [samples][pixels][width][height]
X_train = X_train.reshape(X_train.shape[0], 28, 28, 1).astype('float32')
X_test = X_test.reshape(X_test.shape[0], 28, 28, 1).astype('float32')

# %% [markdown]
# Let's normalize the pixel values to be between 0 and 1

# %%
X_train = X_train / 255 # normalize training data
X_test = X_test / 255 # normalize test data

# %% [markdown]
# Next, let's convert the target variable into binary categories

# %%
y_train = to_categorical(y_train)
y_test = to_categorical(y_test)

num_classes = y_test.shape[1] # number of categories

# %% [markdown]
# Next, let's define a function that creates our model. Let's start with one set of convolutional and pooling layers.

# %%
def convolutional_model():
    
    # create model
    model = Sequential()
    model.add(Input(shape=(28, 28, 1)))
    model.add(Conv2D(16, (5, 5), strides=(1, 1), activation='relu'))
    model.add(MaxPooling2D(pool_size=(2, 2), strides=(2, 2)))
    
    model.add(Flatten())
    model.add(Dense(100, activation='relu'))
    model.add(Dense(num_classes, activation='softmax'))
    
    # compile model
    model.compile(optimizer='adam', loss='categorical_crossentropy',  metrics=['accuracy'])
    return model

# %% [markdown]
# Finally, let's call the function to create the model, and then let's train it and evaluate it.

# %%
# build the model
model = convolutional_model()

# fit the model
model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=10, batch_size=200, verbose=2)

# evaluate the model
scores = model.evaluate(X_test, y_test, verbose=0)
print("Accuracy: {} \n Error: {}".format(scores[1], 100-scores[1]*100))
# Out:
# Epoch 1/10
# 300/300 - 6s - 19ms/step - accuracy: 0.9198 - loss: 0.2838 - val_accuracy: 0.9709 - val_loss: 0.0961
# Epoch 2/10
# 300/300 - 4s - 15ms/step - accuracy: 0.9747 - loss: 0.0854 - val_accuracy: 0.9783 - val_loss: 0.0664
# Epoch 3/10
# 300/300 - 4s - 15ms/step - accuracy: 0.9825 - loss: 0.0586 - val_accuracy: 0.9853 - val_loss: 0.0479
# Epoch 4/10
# 300/300 - 4s - 15ms/step - accuracy: 0.9863 - loss: 0.0467 - val_accuracy: 0.9856 - val_loss: 0.0443
# Epoch 5/10
# 300/300 - 4s - 14ms/step - accuracy: 0.9891 - loss: 0.0365 - val_accuracy: 0.9860 - val_loss: 0.0419
# Epoch 6/10
# 300/300 - 4s - 14ms/step - accuracy: 0.9912 - loss: 0.0296 - val_accuracy: 0.9877 - val_loss: 0.0366
# Epoch 7/10
# 300/300 - 4s - 14ms/step - accuracy: 0.9924 - loss: 0.0246 - val_accuracy: 0.9882 - val_loss: 0.0347
# Epoch 8/10
# 300/300 - 4s - 14ms/step - accuracy: 0.9940 - loss: 0.0202 - val_accuracy: 0.9883 - val_loss: 0.0382
# Epoch 9/10
# 300/300 - 4s - 14ms/step - accuracy: 0.9946 - loss: 0.0179 - val_accuracy: 0.9886 - val_loss: 0.0376
# Epoch 10/10
# 300/300 - 4s - 14ms/step - accuracy: 0.9954 - loss: 0.0151 - val_accuracy: 0.9889 - val_loss: 0.0349
# Accuracy: 0.9889000058174133
#  Error: 1.109999418258667

# %% [markdown]
# ------------------------------------------

# %% [markdown]
# ## Convolutional Neural Network with Two Sets of Convolutional and Pooling Layers

# %% [markdown]
# Let's redefine our convolutional model so that it has two convolutional and pooling layers instead of just one layer of each.

# %%
def convolutional_model():
    
    # create model
    model = Sequential()
    model.add(Input(shape=(28, 28, 1)))
    model.add(Conv2D(16, (5, 5), activation='relu'))
    model.add(MaxPooling2D(pool_size=(2, 2), strides=(2, 2)))
    
    model.add(Conv2D(8, (2, 2), activation='relu'))
    model.add(MaxPooling2D(pool_size=(2, 2), strides=(2, 2)))
    
    model.add(Flatten())
    model.add(Dense(100, activation='relu'))
    model.add(Dense(num_classes, activation='softmax'))
    
    # Compile model
    model.compile(optimizer='adam', loss='categorical_crossentropy',  metrics=['accuracy'])
    return model

# %% [markdown]
# Now, let's call the function to create our new convolutional neural network, and then let's train it and evaluate it.

# %%
# build the model
model = convolutional_model()

# fit the model
model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=10, batch_size=200, verbose=2)

# evaluate the model
scores = model.evaluate(X_test, y_test, verbose=0)
print("Accuracy: {} \n Error: {}".format(scores[1], 100-scores[1]*100))
# Out:
# Epoch 1/10
# 300/300 - 6s - 20ms/step - accuracy: 0.8618 - loss: 0.4761 - val_accuracy: 0.9601 - val_loss: 0.1356
# Epoch 2/10
# 300/300 - 5s - 17ms/step - accuracy: 0.9646 - loss: 0.1190 - val_accuracy: 0.9732 - val_loss: 0.0850
# Epoch 3/10
# 300/300 - 5s - 16ms/step - accuracy: 0.9740 - loss: 0.0858 - val_accuracy: 0.9778 - val_loss: 0.0716
# Epoch 4/10
# 300/300 - 5s - 16ms/step - accuracy: 0.9790 - loss: 0.0694 - val_accuracy: 0.9801 - val_loss: 0.0591
# Epoch 5/10
# 300/300 - 5s - 16ms/step - accuracy: 0.9818 - loss: 0.0598 - val_accuracy: 0.9843 - val_loss: 0.0490
# Epoch 6/10
# 300/300 - 5s - 16ms/step - accuracy: 0.9841 - loss: 0.0512 - val_accuracy: 0.9860 - val_loss: 0.0446
# Epoch 7/10
# 300/300 - 5s - 16ms/step - accuracy: 0.9866 - loss: 0.0450 - val_accuracy: 0.9878 - val_loss: 0.0392
# Epoch 8/10
# 300/300 - 5s - 16ms/step - accuracy: 0.9870 - loss: 0.0416 - val_accuracy: 0.9879 - val_loss: 0.0419
# Epoch 9/10
# 300/300 - 5s - 16ms/step - accuracy: 0.9880 - loss: 0.0382 - val_accuracy: 0.9879 - val_loss: 0.0391
# Epoch 10/10
# 300/300 - 5s - 16ms/step - accuracy: 0.9900 - loss: 0.0340 - val_accuracy: 0.9873 - val_loss: 0.0386
# Accuracy: 0.9872999787330627
#  Error: 1.2700021266937256

# %% [markdown]
# <h3>Practice Exercise 1</h3>

# %% [markdown]
# Let's see how batch size affects the time required and accuracy of the model training.
# For this, you can try to change batch_size to 1024 and check it's effect on accuracy

# %%
# Write your answer here
model = convolutional_model()
model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=10, batch_size=1024, verbose=2)
scores = model.evaluate(X_test, y_test, verbose=0)
print("Accuracy: {} \n Error: {}".format(scores[1], 100-scores[1]*100))
# Out:
# Epoch 1/10
# 59/59 - 7s - 116ms/step - accuracy: 0.6599 - loss: 1.2438 - val_accuracy: 0.8778 - val_loss: 0.4254
# Epoch 2/10
# 59/59 - 5s - 88ms/step - accuracy: 0.8985 - loss: 0.3432 - val_accuracy: 0.9257 - val_loss: 0.2594
# Epoch 3/10
# 59/59 - 6s - 95ms/step - accuracy: 0.9309 - loss: 0.2322 - val_accuracy: 0.9452 - val_loss: 0.1855
# Epoch 4/10
# 59/59 - 5s - 76ms/step - accuracy: 0.9489 - loss: 0.1710 - val_accuracy: 0.9580 - val_loss: 0.1447
# Epoch 5/10
# 59/59 - 5s - 80ms/step - accuracy: 0.9596 - loss: 0.1353 - val_accuracy: 0.9652 - val_loss: 0.1136
# Epoch 6/10
# 59/59 - 5s - 86ms/step - accuracy: 0.9674 - loss: 0.1104 - val_accuracy: 0.9712 - val_loss: 0.0933
# Epoch 7/10
# 59/59 - 7s - 125ms/step - accuracy: 0.9717 - loss: 0.0957 - val_accuracy: 0.9731 - val_loss: 0.0839
# Epoch 8/10
# 59/59 - 10s - 165ms/step - accuracy: 0.9746 - loss: 0.0842 - val_accuracy: 0.9738 - val_loss: 0.0792
# Epoch 9/10
# 59/59 - 10s - 171ms/step - accuracy: 0.9769 - loss: 0.0760 - val_accuracy: 0.9767 - val_loss: 0.0736
# Epoch 10/10
# 59/59 - 10s - 172ms/step - accuracy: 0.9787 - loss: 0.0687 - val_accuracy: 0.9786 - val_loss: 0.0634
# Accuracy: 0.978600025177002
#  Error: 2.1399974822998047

# %% [markdown]
# Double-click <b>here</b> for the solution.
#
# <!-- Your answer is below:
# # build the model
# model = convolutional_model()
#
# # fit the model
# model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=10, batch_size=1024, verbose=2)
#
# # evaluate the model
# scores = model.evaluate(X_test, y_test, verbose=0)
# print("Accuracy: {} \n Error: {}".format(scores[1], 100-scores[1]*100))
# -->

# %% [markdown]
# <h3>Practice Exercise 2</h3>

# %% [markdown]
# Now, let's see how number of epochs  affect the time required and accuracy of the model training.
# For this, you can keep the batch_size=1024 and epochs=25 and check it's effect on accuracy

# %%
# Write your answer here

# Write your answer here
model = convolutional_model()
model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=25, batch_size=1024, verbose=2)
scores = model.evaluate(X_test, y_test, verbose=0)
print("Accuracy: {} \n Error: {}".format(scores[1], 100-scores[1]*100))
# Out:
# Epoch 1/25
# 59/59 - 18s - 299ms/step - accuracy: 0.5907 - loss: 1.4755 - val_accuracy: 0.8778 - val_loss: 0.4402
# Epoch 2/25
# 59/59 - 11s - 187ms/step - accuracy: 0.9163 - loss: 0.2961 - val_accuracy: 0.9451 - val_loss: 0.1894
# Epoch 3/25
# 59/59 - 11s - 183ms/step - accuracy: 0.9488 - loss: 0.1770 - val_accuracy: 0.9598 - val_loss: 0.1325
# Epoch 4/25
# 59/59 - 10s - 170ms/step - accuracy: 0.9606 - loss: 0.1356 - val_accuracy: 0.9700 - val_loss: 0.1074
# Epoch 5/25
# 59/59 - 2066s - 35s/step - accuracy: 0.9674 - loss: 0.1124 - val_accuracy: 0.9731 - val_loss: 0.0910
# Epoch 6/25
# 59/59 - 15s - 254ms/step - accuracy: 0.9713 - loss: 0.0978 - val_accuracy: 0.9778 - val_loss: 0.0774
# Epoch 7/25
# 59/59 - 12s - 196ms/step - accuracy: 0.9745 - loss: 0.0862 - val_accuracy: 0.9767 - val_loss: 0.0743
# Epoch 8/25
# 59/59 - 12s - 207ms/step - accuracy: 0.9761 - loss: 0.0796 - val_accuracy: 0.9792 - val_loss: 0.0643
# Epoch 9/25
# 59/59 - 10s - 177ms/step - accuracy: 0.9786 - loss: 0.0722 - val_accuracy: 0.9810 - val_loss: 0.0597
# Epoch 10/25
# 59/59 - 15s - 253ms/step - accuracy: 0.9804 - loss: 0.0666 - val_accuracy: 0.9826 - val_loss: 0.0569
# Epoch 11/25
# 59/59 - 15s - 246ms/step - accuracy: 0.9815 - loss: 0.0631 - val_accuracy: 0.9831 - val_loss: 0.0525
# Epoch 12/25
# 59/59 - 14s - 233ms/step - accuracy: 0.9824 - loss: 0.0593 - val_accuracy: 0.9834 - val_loss: 0.0542
# Epoch 13/25
# 59/59 - 16s - 267ms/step - accuracy: 0.9823 - loss: 0.0582 - val_accuracy: 0.9838 - val_loss: 0.0517
# Epoch 14/25
# 59/59 - 10s - 171ms/step - accuracy: 0.9836 - loss: 0.0549 - val_accuracy: 0.9831 - val_loss: 0.0507
# Epoch 15/25
# 59/59 - 12s - 197ms/step - accuracy: 0.9845 - loss: 0.0510 - val_accuracy: 0.9850 - val_loss: 0.0485
# Epoch 16/25
# 59/59 - 14s - 238ms/step - accuracy: 0.9851 - loss: 0.0496 - val_accuracy: 0.9856 - val_loss: 0.0441
# Epoch 17/25
# 59/59 - 11s - 180ms/step - accuracy: 0.9864 - loss: 0.0463 - val_accuracy: 0.9845 - val_loss: 0.0463
# Epoch 18/25
# 59/59 - 12s - 196ms/step - accuracy: 0.9869 - loss: 0.0448 - val_accuracy: 0.9861 - val_loss: 0.0419
# Epoch 19/25
# 59/59 - 11s - 186ms/step - accuracy: 0.9873 - loss: 0.0431 - val_accuracy: 0.9843 - val_loss: 0.0436
# Epoch 20/25
# 59/59 - 10s - 177ms/step - accuracy: 0.9874 - loss: 0.0423 - val_accuracy: 0.9863 - val_loss: 0.0446
# Epoch 21/25
# 59/59 - 9s - 158ms/step - accuracy: 0.9880 - loss: 0.0404 - val_accuracy: 0.9860 - val_loss: 0.0437
# Epoch 22/25
# 59/59 - 10s - 168ms/step - accuracy: 0.9887 - loss: 0.0381 - val_accuracy: 0.9867 - val_loss: 0.0400
# Epoch 23/25
# 59/59 - 10s - 173ms/step - accuracy: 0.9883 - loss: 0.0389 - val_accuracy: 0.9859 - val_loss: 0.0420
# Epoch 24/25
# 59/59 - 11s - 184ms/step - accuracy: 0.9884 - loss: 0.0381 - val_accuracy: 0.9884 - val_loss: 0.0372
# Epoch 25/25
# 59/59 - 11s - 178ms/step - accuracy: 0.9895 - loss: 0.0352 - val_accuracy: 0.9875 - val_loss: 0.0385
# Accuracy: 0.987500011920929
#  Error: 1.2499988079071045

# %% [markdown]
# Double-click <b>here</b> for the solution.
#
# <!-- Your answer is below:
# # build the model
# model = convolutional_model()
#
# # fit the model
# model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=25, batch_size=1024, verbose=2)
#
# # evaluate the model
# scores = model.evaluate(X_test, y_test, verbose=0)
# print("Accuracy: {} \n Error: {}".format(scores[1], 100-scores[1]*100))
#
#
#     -->

# %% [markdown]
# ### Thank you for completing this lab!
#
# This notebook was created by [Alex Aklson](https://www.linkedin.com/in/aklson/). I hope you found this lab interesting and educational. Feel free to contact me if you have any questions!

# %% [markdown]
# <!--
# ## Change Log
#
# |  Date (YYYY-MM-DD) |  Version | Changed By  |  Change Description |
# |---|---|---|---|
# | 2024-11-20  | 3.0  | Aman  |  Updated the library versions to current |
# | 2020-09-21  | 2.0  | Srishti  |  Migrated Lab to Markdown and added to course repo in GitLab |
#
#
#
# <hr>
#
# ## <h3 align="center"> © IBM Corporation. All rights reserved. <h3/>

# %% [markdown]
# ## <h3 align="center"> &#169; IBM Corporation. All rights reserved. <h3/>
